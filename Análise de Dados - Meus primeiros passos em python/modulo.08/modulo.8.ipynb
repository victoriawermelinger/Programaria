# %% [markdown]
# # **8.1 - Inspire-se com essas mulheres | Apresentação**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # **8.2 - Inspire-se com essas mulheres | Desafios**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # **8.3 - Inspire-se com essas mulheres | Dicas**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # **8.4 - Inspire-se com essas mulheres | Cases de carreira**
#
# https://import.cdn.thinkific.com/584413/XhX54Pb7R9uhKzubXdmr_EuProgramo_AD1__Cases-Carreira.pdf

# %% [markdown]
# # **8.5 - Referências para ir além**
#
# ![image.png](attachment:image.png)
#
# Referências para ir além - PrograMaria Sprint de Dados https://www.programaria.org/ciencia-dados-referencias-ir-alem/?_gl=1
#
# UNIVESP - Universidade pública exclusivamente voltado para educação à distância     https://univesp.br/cursos
#
# Canal Programação Dinâmica      https://www.youtube.com/channel/UC70mr11REaCqgKke7DPJoLg
#
# Roda de conversa sobre "Tecnologia sob lentes feministas"       https://www.youtube.com/watch?v=5wMazziU8pk

# %% [markdown]
# # **8.6 - Conte sobre sua jornada!**
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)
