# %% [markdown]
# # **7.1 - O que é aprendizado de máquina**
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# O que é Machine Learning? | Alura       https://www.alura.com.br/artigos/machine-learning
#
# O que é Inteligência Artificial? *e o que NÃO É Também!* | IA Descomplicada #01         https://www.youtube.com/watch?v=pO0wlaxqWXg&list=PL5TJqBvpXQv4vYX3Ki2Kn3MLYIiny1a5H
#
# O que é MACHINE LEARNING? Introdução ao APRENDIZADO DE MÁQUINA | Machine Learning #1        https://www.youtube.com/watch?v=u8xgqvk16EA&list=PL5TJqBvpXQv6EuU821pKje6q-yfPMO8re&index=8
#
# Regressão Linear?. Um dos modelos de machine learning mais… | by Laura Damaceno | Medium        https://medium.com/@lauradamaceno/regress%C3%A3o-linear-6a7f247c3e29

# %% [markdown]
# # **7.2 - Preparação dos dados (parte 1)**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # **7.2 - Preparação dos dados (parte 2)**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # **7.2 - Preparação dos dados (parte 3)**
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
#
# https://files.cdn.thinkific.com/file_uploads/584413/attachments/07b/5c4/f4e/analise_dados_mod7_%281%29.xlsx

# %% [markdown]
# # **7.3 - Introdução a regressão linear (parte 1)**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # **7.3 - Introdução a regressão linear (parte 2)**
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# Entendendo Regressão Linear: as suposições por trás de tudo! | by Laura Damaceno | Medium
# https://medium.com/@lauradamaceno/entendendo-regress%C3%A3o-linear-as-suposi%C3%A7%C3%B5es-por-tr%C3%A1s-de-tudo-d0e29004c7f8
#
# Desmistificando a Regressão Linear      https://www.youtube.com/watch?v=ZOk4cuwaon4
#
#
#
# Viés de Dados com Vivi Mota     https://www.youtube.com/watch?v=k_fOVk-o4Iw

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
